# %%
import subprocess, os
os.chdir("/home/amluser/amlSettings/SLM/pairwise")
os.makedirs("../logs", exist_ok=True)
lf = open("../logs/pairwise_nohup.log", "w")
p = subprocess.Popen(["bash", "run_full.sh"], stdout=lf, stderr=subprocess.STDOUT)
print(f"Started PID={p.pid}")
print(f"Log: ../logs/pairwise_nohup.log")
